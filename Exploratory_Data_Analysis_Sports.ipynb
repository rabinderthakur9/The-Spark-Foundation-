# %% [markdown]
# <a href="https://colab.research.google.com/github/rabinderthakur9/The-Spark-Foundation-/blob/main/Exploratory_Data_Analysis_Sports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![The Spark Foundation Banner 1.png](data:image/png;base64,...)

# %% [markdown]
# # The Spark Foundation Task 5
# ## Auther : Rabindar Thakur
#
# Problem Defination: Exploratory Data Analysis on IPL Datasets

# %%
#Importing libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
#importing the datasets from the drive
delivery = pd.read_csv("/content/drive/MyDrive/Indian Premier League/deliveries.csv")
match = pd.read_csv("/content/drive/MyDrive/Indian Premier League/matches.csv")

# %%
#Delivery data
delivery.head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
#match data
match.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
#shape of delivery data
delivery.shape
# Out:
# (179078, 21)

# %%
#shape of delivery data
match.shape
# Out:
# (756, 18)

# %%
#Checking the Null Values in the delivery dataset
delivery.isnull().sum()
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    170244
# dismissal_kind      170244
# fielder             172630
# dtype: int64

# %%
#checking the null values in the match dataset
match.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
#checking the duplicate values in the match dataset
delivery.duplicated().sum()
# Out:
# 23

# %%
#checking the duplicate values in the match dataset
match.duplicated().sum()
# Out:
# 0

# %%
#info of the delivery dataset
delivery.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
#info of the match dataset
match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
#columns in delivery
delivery.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
#plotting the balls by total runs
delivery.head(50).plot(x='ball',y='total_runs')

# %%
#filtering the data with the ball over
delivery[delivery['over']==1].head()
# Out:
#    match_id  inning  ... dismissal_kind fielder
# 0         1       1  ...            NaN     NaN
# 1         1       1  ...            NaN     NaN
# 2         1       1  ...            NaN     NaN
# 3         1       1  ...            NaN     NaN
# 4         1       1  ...            NaN     NaN
#
# [5 rows x 21 columns]

# %%
#getting the total of runs in one over
over=delivery[(delivery['match_id']==1)]['over']
run=delivery[(delivery['match_id']==1) & (delivery['over']==1)]['total_runs'].sum()
run
# Out:
# 18

# %%
#plotting the over
(delivery['over'].value_counts()/6).plot(kind='bar')

# %%
#groupping the matchid,innings,batting team and the batsmen to see who have scored most runs in the match
batsman_grp = delivery.groupby(["match_id", "inning", "batting_team", "batsman"])
batsmen = batsman_grp["batsman_runs"].sum().reset_index()
batsmen = match[['id','season']].merge(batsmen, left_on = 'id', right_on = 'match_id', how = 'left').drop('id', axis = 1)

# %%
#data of the team and the batsmen
batsmen.head()
# Out:
#    season  match_id  inning         batting_team       batsman  batsman_runs
# 0    2017         1       1  Sunrisers Hyderabad   BCJ Cutting            16
# 1    2017         1       1  Sunrisers Hyderabad     DA Warner            14
# 2    2017         1       1  Sunrisers Hyderabad      DJ Hooda            16
# 3    2017         1       1  Sunrisers Hyderabad  MC Henriques            52
# 4    2017         1       1  Sunrisers Hyderabad      S Dhawan            40

# %%
#plotting the top 6 batsmen with the most amount of runs
batsman_runsperseason = batsmen.groupby(['season', 'batting_team', 'batsman'])['batsman_runs'].sum().reset_index()
batsman_runsperseason = batsman_runsperseason.groupby(['season', 'batsman'])['batsman_runs'].sum().unstack().T
batsman_runsperseason['Total'] = batsman_runsperseason.sum(axis=1)
batsman_runsperseason = batsman_runsperseason.sort_values(by = 'Total', ascending = False).drop('Total', 1)
ax = batsman_runsperseason[:7].T.plot()

# %%
#data showing the top 10 batsmen with the most runs in different seasons
batsman_runsperseason.head()
# Out:
# season      2008   2009   2010   2011   2012  ...   2015   2016   2017   2018   2019
# batsman                                       ...
# V Kohli    165.0  246.0  307.0  557.0  364.0  ...  505.0  973.0  308.0  539.0  472.0
# SK Raina   421.0  434.0  528.0  438.0  441.0  ...  374.0  399.0  442.0  466.0  401.0
# RG Sharma  404.0  362.0  404.0  372.0  433.0  ...  482.0  489.0  333.0  297.0  410.0
# DA Warner    NaN  163.0  282.0  324.0  256.0  ...  562.0  848.0  641.0    NaN  727.0
# S Dhawan   340.0   40.0  191.0  400.0  569.0  ...  353.0  501.0  479.0  529.0  542.0
#
# [5 rows x 12 columns]

# %% [markdown]
# ## Now Lets Analyse The Match

# %%
match.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar       NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 4   5    2017  Bangalore  ...             NaN            NaN     NaN
#
# [5 rows x 18 columns]

# %%
match.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
#plotting the mot played venue in for the IPL 


sns.set_style("darkgrid")
ls=match['venue'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(15,8))
temp =sns.barplot(ls.index, ls.values, alpha=0.8)
plt.title('MOST PLAYED VENUE')
plt.ylabel('COUNT', fontsize=14)
plt.xlabel('NAME OF THE STADIUMS', fontsize=15)
temp.set_xticklabels(rotation=90,labels=ls.index,fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#Count of the man of the match batsman
match['player_of_match'].value_counts()
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# RG Sharma         17
# MS Dhoni          17
#                   ..
# Z Khan             1
# RA Tripathi        1
# L Ngidi            1
# J Theron           1
# Umar Gul           1
# Name: player_of_match, Length: 226, dtype: int64

# %%
#Top Ten player for the player of the match
match['player_of_match'].value_counts()[0:10]
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# RG Sharma         17
# MS Dhoni          17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %%
#listing the top 10 man of the match batsmen
list(match['player_of_match'].value_counts()[0:10].keys())
# Out:
# ['CH Gayle',
#  'AB de Villiers',
#  'DA Warner',
#  'RG Sharma',
#  'MS Dhoni',
#  'YK Pathan',
#  'SR Watson',
#  'SK Raina',
#  'G Gambhir',
#  'MEK Hussey']

# %%
#ctrl+m z cell undo
#Getting the frequency of result column
match['result'].value_counts()
# Out:
# normal       743
# tie            9
# no result      4
# Name: result, dtype: int64

# %%
#including the number of toss wins by teams
match['toss_winner'].value_counts()
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Rajasthan Royals               80
# Delhi Daredevils               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
#extracting the records of where a teamwon batting tfirst
bat_first=match[match['win_by_runs']!=0]

# %%
bat_first.head()
# Out:
#     id  season       city  ...      umpire1      umpire2 umpire3
# 0    1    2017  Hyderabad  ...  AY Dandekar     NJ Llong     NaN
# 4    5    2017  Bangalore  ...          NaN          NaN     NaN
# 8    9    2017       Pune  ...  AY Dandekar       S Ravi     NaN
# 13  14    2017    Kolkata  ...  AY Dandekar     NJ Llong     NaN
# 14  15    2017      Delhi  ...     YC Barde  Nitin Menon     NaN
#
# [5 rows x 18 columns]

# %%
#plotting the win by runs

plt.figure(figsize=(8,7))
plt.hist(bat_first['win_by_runs'])
plt.title('Distribution of Runs')
plt.xlabel("Runs")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#finding the teams winners with the teams batting first
bat_first['winner'].value_counts()[0:10]
# Out:
# Mumbai Indians                 57
# Chennai Super Kings            52
# Kings XI Punjab                38
# Kolkata Knight Riders          36
# Royal Challengers Bangalore    35
# Sunrisers Hyderabad            30
# Rajasthan Royals               27
# Delhi Daredevils               25
# Deccan Chargers                18
# Pune Warriors                   6
# Name: winner, dtype: int64

# %%
#Top 3 winning team in IPL when team decided to bat first

plt.figure(figsize=(10,8))
plt.bar(list (bat_first['winner'].value_counts()[0:5].keys()),
        list (bat_first['winner'].value_counts()[0:5]),color=['green','yellow','orange','Blue','Cyan'])
plt.show()

# %%
#most number of times team won when the team have choosen to go for batting first

plt.figure(figsize=(18,10))
plt.pie(list (bat_first['winner'].value_counts()),
        labels= list(bat_first['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.legend(loc='best')

# %%
#extracting the records where the teams have won the match by second
bat_sec=match[match['win_by_wickets']!=0]
bat_sec.head()
# Out:
#    id  season       city  ...         umpire1        umpire2 umpire3
# 1   2    2017       Pune  ...  A Nand Kishore         S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon      CK Nandan     NaN
# 3   4    2017     Indore  ...    AK Chaudhary  C Shamshuddin     NaN
# 5   6    2017  Hyderabad  ...      A Deshmukh       NJ Llong     NaN
# 6   7    2017     Mumbai  ...     Nitin Menon      CK Nandan     NaN
#
# [5 rows x 18 columns]

# %%
#Number of wins when team decided to bat second
plt.figure(figsize=(7,8))
plt.hist(bat_sec['win_by_wickets'],bins=10)
plt.show()

# %%
#Number of winning times when team decided to bat second
bat_sec['winner'].value_counts()
# Out:
# Kolkata Knight Riders          56
# Mumbai Indians                 50
# Chennai Super Kings            48
# Royal Challengers Bangalore    48
# Rajasthan Royals               46
# Delhi Daredevils               42
# Kings XI Punjab                42
# Sunrisers Hyderabad            27
# Gujarat Lions                  12
# Deccan Chargers                11
# Pune Warriors                   6
# Delhi Capitals                  6
# Rising Pune Supergiant          5
# Kochi Tuskers Kerala            4
# Rising Pune Supergiants         3
# Name: winner, dtype: int64

# %%
#top 5 teams to won when they have choosen to go batting second
plt.figure(figsize=(10,6))
plt.bar(list (bat_sec['winner'].value_counts()[0:5].keys()),
        list (bat_sec['winner'].value_counts().value_counts()[0:5]),color=['purple','green','red','blue','Cyan'])
plt.show()

# %%
#figure showing the teams won by choosing to go second batting
plt.figure(figsize=(18,10))
plt.pie(list (bat_sec['winner'].value_counts()),
        labels= list(bat_sec['winner'].value_counts().keys()),autopct='%0.1f%%')
plt.legend(loc='best')

# %%
#Number of Season in IPL
match['season'].value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2019    60
# 2018    60
# 2016    60
# 2014    60
# 2010    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
#most number of matches played in the cities
match['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Mohali             10
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Ranchi              7
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
sns.set_style("darkgrid")
city=match['city'].value_counts().sort_values(ascending=False)
plt.figure(figsize=(15,8))
temp =sns.barplot(city.index, city.values, alpha=0.8)
plt.title('MOST PLAYED CITY')
plt.ylabel('COUNT', fontsize=14)
plt.xlabel('NAME OF THE CITY', fontsize=15)
temp.set_xticklabels(rotation=90,labels=city.index,fontsize=10)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#finding out how many teams who have won after they have won the toss

import numpy as np

np.sum(match['toss_winner']==match['winner'])
# Out:
# 393

# %%
#Winning and loosing of the match in different seasons

import numpy as np
toss = match.groupby(['season', 'toss_winner']).winner.value_counts().reset_index(name = 'count')
toss['result'] = np.where(toss.toss_winner == toss.winner, 'won', 'lost')
toss_result = toss.groupby(['season', 'toss_winner','result'])['count'].sum().reset_index()

for x in range(2008, 2017, 1):
    toss_result_x = toss_result[toss_result['season'] == x]
    plot = sns.barplot(x="toss_winner", y="count", hue="result", data=toss_result_x)
    plot.set_title('Matches won/lost by teams winning toss \nSeason ' +str(x))
    plot.set_xticklabels(toss_result_x['toss_winner'],rotation=30)
    plt.show()
    x+=1
